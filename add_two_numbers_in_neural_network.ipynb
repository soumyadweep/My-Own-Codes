# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadweep/File-handling-in-python-1/blob/main/add_two_numbers_in_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
X = []
y = []
for i in range(500):
  X.append([np.random.randint(1,1000),np.random.randint(1,1000)])
  y.append(sum(X[i]))
##for i in range(250):
  #X.append([- np.random.randint(1,1000),np.random.randint(1,1000)])
  #y.append(sum(X[i]))
print(X)
print(y)
# Out:
# [[901, 353], [672, 242], [591, 22], [169, 224], [417, 421], [243, 377], [867, 794], [446, 686], [61, 746], [938, 319], [238, 613], [888, 985], [921, 600], [14, 558], [941, 586], [369, 200], [526, 668], [298, 166], [128, 171], [6, 481], [495, 902], [201, 871], [351, 157], [761, 123], [882, 782], [276, 675], [855, 116], [696, 619], [724, 502], [939, 156], [536, 661], [585, 173], [453, 385], [1, 211], [998, 891], [405, 614], [314, 575], [471, 812], [991, 747], [155, 743], [377, 654], [781, 913], [511, 994], [247, 267], [533, 42], [650, 33], [643, 983], [553, 766], [190, 29], [686, 191], [70, 151], [527, 316], [754, 760], [123, 730], [5, 158], [315, 623], [627, 130], [544, 326], [509, 63], [436, 800], [654, 358], [301, 37], [850, 930], [693, 146], [919, 51], [372, 823], [979, 934], [483, 900], [853, 2], [764, 64], [634, 374], [175, 136], [639, 331], [280, 754], [986, 633], [506, 556], [640, 917], [483, 209], [958, 289], [185, 418], [707, 496], [127, 147], [252, 930], [242, 839], [283, 50
# ...

# %%
tf.random.set_seed(42)
model = Sequential([
    tf.keras.Input(shape=(2,)),
    Dense(units = 2, activation = 'linear'),
    Dense(units = 1)
])

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001),loss = 'mean_squared_error')

# %%
model.fit(X,y, epochs = 500)
# Out:
# Epoch 1/500
# 16/16 [==============================] - 0s 1ms/step - loss: 276844.8750
# Epoch 2/500
# 16/16 [==============================] - 0s 1ms/step - loss: 230754.4844
# Epoch 3/500
# 16/16 [==============================] - 0s 1ms/step - loss: 191659.7031
# Epoch 4/500
# 16/16 [==============================] - 0s 1ms/step - loss: 159395.0781
# Epoch 5/500
# 16/16 [==============================] - 0s 1ms/step - loss: 133311.8906
# Epoch 6/500
# 16/16 [==============================] - 0s 1ms/step - loss: 112578.6641
# Epoch 7/500
# 16/16 [==============================] - 0s 1ms/step - loss: 96335.6328
# Epoch 8/500
# 16/16 [==============================] - 0s 1ms/step - loss: 83757.5625
# Epoch 9/500
# 16/16 [==============================] - 0s 1ms/step - loss: 74085.6094
# Epoch 10/500
# 16/16 [==============================] - 0s 1ms/step - loss: 66648.2344
# Epoch 11/500
# 16/16 [==============================] - 0s 1ms/step - loss: 60875.2617
# Epoch 12/500
# ...

# %%
testdata = np.array([[2,3],[3,44],[-2,1.0]])
pred = model.predict(testdata)
pred
# Out:
# 1/1 [==============================] - 0s 34ms/step
# array([[ 5.349477  ],
#        [47.337112  ],
#        [-0.64859366]], dtype=float32)
